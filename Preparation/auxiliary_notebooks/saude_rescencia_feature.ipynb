# %%
import pandas as pd

df = pd.read_csv('data/estaticos_portfolio1.csv',index_col=0)

df['de_saude_rescencia'].value_counts()
# Out:
# ACIMA DE 1 ANO    453
# ATE 1 ANO          55
# SEM INFORMACAO     36
# Name: de_saude_rescencia, dtype: int64

# %%
df.shape
# Out:
# (555, 181)

# %%
df['de_saude_rescencia'].value_counts().sum()
# Out:
# 544

# %%
df['de_saude_rescencia'] = df['de_saude_rescencia'].fillna('SEM INFORMACAO')

# %%
df['de_saude_rescencia']
# Out:
# 0      SEM INFORMACAO
# 1      ACIMA DE 1 ANO
# 2      ACIMA DE 1 ANO
# 3      ACIMA DE 1 ANO
# 4      ACIMA DE 1 ANO
#             ...
# 550    ACIMA DE 1 ANO
# 551         ATE 1 ANO
# 552    ACIMA DE 1 ANO
# 553         ATE 1 ANO
# 554    ACIMA DE 1 ANO
# Name: de_saude_rescencia, Length: 555, dtype: object

# %%
def create_dummy_df(df, cat_cols, dummy_na):
    '''
    INPUT:
    df - pandas dataframe with categorical variables you want to dummy
    cat_cols - list of strings that are associated with names of the categorical columns
    dummy_na - Bool holding whether you want to dummy NA vals of categorical columns or not
    
    OUTPUT:
    df - a new dataframe that has the following characteristics:
            1. contains all columns that were not specified as categorical
            2. removes all the original columns in cat_cols
            3. dummy columns for each of the categorical columns in cat_cols
            4. if dummy_na is True - it also contains dummy columns for the NaN values
            5. Use a prefix of the column name with an underscore (_) for separating 
    '''
    for col in  cat_cols:
        try:
            #for each cat add dummy var, drop original column
            df = pd.concat([df.drop(columns=col, axis=1), pd.get_dummies(df[col], prefix=col, prefix_sep='_', drop_first=False, dummy_na=dummy_na)], axis=1)
        except:
            continue
    return df;

# %%
df.head()
# Out:
#                                                   id  fl_matriz  \
# 0  dabe79bec87c88ae04e869bf6bd321ee5e1893cecf6625...       True
# 1  32e5f4e10932153a7ba869cb0386e7e02d49d2461046b8...      False
# 2  a95d6f30bba445bd3d6b0c5b36f865b38ec01d17336090...       True
# 3  6cb309685cea0b6d2988818792ec2e6fcb2bd02e0afa9e...       True
# 4  f72aa7fa6787b0a5a1c88885b6120850df8ee0f71adc25...       True
#
#             de_natureza_juridica sg_uf natureza_juridica_macro  \
# 0          EMPRESARIO INDIVIDUAL    PI                  OUTROS
# 1          EMPRESARIO INDIVIDUAL    MA                  OUTROS
# 2          EMPRESARIO INDIVIDUAL    MA                  OUTROS
# 3          EMPRESARIO INDIVIDUAL    RN                  OUTROS
# 4  SOCIEDADE EMPRESARIA LIMITADA    RN  ENTIDADES EMPRESARIAIS
#
#               de_ramo     setor  idade_empresa_anos idade_emp_cat  fl_me  ...  \
# 0  COMERCIO VAREJISTA  COMERCIO            0.646575          <= 1  False  ...
# ...

# %%
cat_cols = ['de_saude_rescencia']
create_dummy_df(df, cat_cols, False)
# Out:
#                                                     id  fl_matriz  \
# 0    dabe79bec87c88ae04e869bf6bd321ee5e1893cecf6625...       True
# 1    32e5f4e10932153a7ba869cb0386e7e02d49d2461046b8...      False
# 2    a95d6f30bba445bd3d6b0c5b36f865b38ec01d17336090...       True
# 3    6cb309685cea0b6d2988818792ec2e6fcb2bd02e0afa9e...       True
# 4    f72aa7fa6787b0a5a1c88885b6120850df8ee0f71adc25...       True
# ..                                                 ...        ...
# 550  4e2353206c04c6a8c097252c89f6970594f0796676bba5...       True
# 551  571a7461978f95114944695065e774a38f06528d287740...       True
# 552  4fbebb5a4ea9d2c5da87f446aff48403f0409e2e8fe381...       True
# 553  8bbff0a749bceb9749c5edd90373270ff9109f069ef27c...       True
# 554  970485e6b8abe52d8fb4e0bf060fb6f0f4f8576cb7583d...       True
#
#               de_natureza_juridica sg_uf natureza_juridica_macro  \
# 0            EMPRESARIO INDIVIDUAL    PI                  OUTROS
# ...

# %%
set(df.columns)
# Out:
# {'coligada_mais_antiga_ativa',
#  'coligada_mais_antiga_baixada',
#  'coligada_mais_nova_ativa',
#  'coligada_mais_nova_baixada',
#  'de_faixa_faturamento_estimado',
#  'de_faixa_faturamento_estimado_grupo',
#  'de_indicador_telefone',
#  'de_natureza_juridica',
#  'de_nivel_atividade',
#  'de_ramo',
#  'de_saude_rescencia',
#  'de_saude_tributaria',
#  'dt_situacao',
#  'empsetorcensitariofaixarendapopulacao',
#  'faturamento_est_coligados',
#  'faturamento_est_coligados_gp',
#  'fl_antt',
#  'fl_email',
#  'fl_epp',
#  'fl_ltda',
#  'fl_matriz',
#  'fl_me',
#  'fl_mei',
#  'fl_optante_simei',
#  'fl_optante_simples',
#  'fl_passivel_iss',
#  'fl_rm',
#  'fl_sa',
#  'fl_simples_irregular',
#  'fl_spa',
#  'fl_st_especial',
#  'fl_telefone',
#  'fl_veiculo',
#  'grau_instrucao_macro_analfabeto',
#  'grau_instrucao_macro_desconhecido',
#  'grau_instrucao_macro_escolaridade_fundamental',
#  'grau_instrucao_macro_escolaridade_media',
#  'grau_instrucao_macro_escolaridade_superior',
# ...
